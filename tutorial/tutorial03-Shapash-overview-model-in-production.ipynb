# %% [markdown]
# # Shapash in Jupyter - Overview
#
# <b>With this tutorial you:</b><br />
# Understand how Shapash works in Jupyter Notebook
# with a simple use case<br />
#
# Contents:
# - Build a Regressor
# - Compile Shapash SmartExplainer
# - Compile Shapash SmartExplainer to SmartPredictor
# - Save Shapash Smartpredictor Object in pickle file
# - Make a prediction
#
# Data from Kaggle [House Prices](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data)

# %%
import pandas as pd
from category_encoders import OrdinalEncoder
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Building Supervized Model

# %%
import sys
sys.path.insert(0,'/home/78257d/shapash/')
from shapash.explainer.smart_predictor import SmartPredictor
from shapash.explainer.smart_explainer import SmartExplainer
from shapash.data.data_loader import data_loading
from shapash.utils.load_smartpredictor import load_smartpredictor
#from shapash.data.data_loader import data_loading
house_df, house_dict = data_loading('house_prices')

# %%
y_df=house_df['SalePrice'].to_frame()
X_df=house_df[house_df.columns.difference(['SalePrice'])]

# %%
house_df.head()
# Out:
#                          MSSubClass                 MSZoning  LotArea Street  \
# Id
# 1              2-Story 1946 & Newer  Residential Low Density     8450  Paved
# 2   1-Story 1946 & Newer All Styles  Residential Low Density     9600  Paved
# 3              2-Story 1946 & Newer  Residential Low Density    11250  Paved
# 4              2-Story 1945 & Older  Residential Low Density     9550  Paved
# 5              2-Story 1946 & Newer  Residential Low Density    14260  Paved
#
#               LotShape      LandContour                         Utilities  \
# Id
# 1              Regular  Near Flat/Level  All public Utilities (E,G,W,& S)
# 2              Regular  Near Flat/Level  All public Utilities (E,G,W,& S)
# 3   Slightly irregular  Near Flat/Level  All public Utilities (E,G,W,& S)
# 4   Slightly irregular  Near Flat/Level  All public Utilities (E,G,W,& S)
# 5   Slightly irregular  Near Flat/Level  All public Utilities (E,G,W,& S)
#
#                           LotConfig     LandSlope   Neighborhood  ...  \
# Id                                                                ...
# 1                        Inside lot  Gentle slope  College Creek  ...
# 2   Frontage on 2 sides of property  Gentle slope        Veenker  ...
# 3                        Inside lot  Gentle slope  College Creek  ...
# 4                        Corner lot  Gentle slope       Crawford  ...
# 5   Frontage on 2 sides of property  Gentle slope     Northridge  ...
#
#    EnclosedPorch 3SsnPorch ScreenPorch PoolArea  MiscVal  MoSold  YrSold  \
# Id
# 1              0         0           0        0        0       2    2008
# 2              0         0           0        0        0       5    2007
# 3              0         0           0        0        0       9    2008
# 4            272         0           0        0        0       2    2006
# 5              0         0           0        0        0      12    2008
#
#                         SaleType  SaleCondition SalePrice
# Id
# 1   Warranty Deed - Conventional    Normal Sale    208500
# 2   Warranty Deed - Conventional    Normal Sale    181500
# 3   Warranty Deed - Conventional    Normal Sale    223500
# 4   Warranty Deed - Conventional  Abnormal Sale    140000
# 5   Warranty Deed - Conventional    Normal Sale    250000
#
# [5 rows x 73 columns]

# %% [markdown]
# #### Encoding Categorical Features

# %%
from category_encoders import OrdinalEncoder

categorical_features = [col for col in X_df.columns if X_df[col].dtype == 'object']

encoder = OrdinalEncoder(
    cols=categorical_features,
    handle_unknown='ignore',
    return_df=True).fit(X_df)

X_df=encoder.transform(X_df)
# Out:
# /home/78257d/.conda/envs/test_env_shapash/lib/python3.6/site-packages/category_encoders/utils.py:21: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead

# %% [markdown]
# #### Train / Test Split

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X_df, y_df, train_size=0.75, random_state=1)

# %% [markdown]
# #### Model Fitting

# %%
regressor = LGBMRegressor(n_estimators=200).fit(Xtrain,ytrain)

# %%
y_pred = pd.DataFrame(regressor.predict(Xtest),columns=['pred'],index=Xtest.index)

# %% [markdown]
# ## Understand my model with shapash

# %% [markdown]
# #### Declare and Compile SmartExplainer

# %%
from shapash.explainer.smart_explainer import SmartExplainer

# %%
xpl = SmartExplainer()

# %%
xpl.compile(
    x=Xtest,
    model=regressor,
    preprocessing=encoder, # Optional: compile step can use inverse_transform method
    y_pred=y_pred # Optional
)
# Out:
# Backend: Shap TreeExplainer

# %% [markdown]
# #### Compile SmartExplainer to SmartPredictor

# %%
predictor = xpl.to_smartpredictor()

# %% [markdown]
# ## Save and Load your Predictor

# %% [markdown]
# #### Save your predictor in Pickle File

# %%
predictor.save('./predictor.pkl')

# %% [markdown]
# #### Load your predictor in Pickle File

# %%
predictor_load = load_smartpredictor('./predictor.pkl')

# %% [markdown]
# ## Make a prediction with your Predictor

# %% [markdown]
# #### Add data

# %%
predictor_load.add_input(x=X_df, ypred=y_df)

# %% [markdown]
# #### Make prediction

# %%
prediction = predictor_load.predict()

# %%
prediction.head()
# Out:
#             ypred
# Id
# 1   206462.878757
# 2   181127.963794
# 3   221478.052244
# 4   184788.423141
# 5   256637.518234

# %% [markdown]
# #### Get detailed explanability associated to the prediction

# %%
detailed_contributions = predictor_load.detail_contributions()

# %%
detailed_contributions.head()
# Out:
#             ypred     1stFlrSF     2ndFlrSF  3SsnPorch  BedroomAbvGr  \
# Id
# 1   206462.878757 -1104.994176  1281.445856        0.0    375.679661
# 2   181127.963794  1629.056157  -683.689921        0.0    127.177790
# 3   221478.052244 -1321.131971  -556.399274        0.0    361.547835
# 4   184788.423141  -991.578703    20.078384        0.0    310.409913
# 5   256637.518234 -8807.740743 -1061.015056        0.0  -1580.357621
#
#      BldgType    BsmtCond  BsmtExposure   BsmtFinSF1  BsmtFinSF2  ...  \
# Id                                                                ...
# 1   12.259902  157.224629   -233.025420  -738.445396  -59.294761  ...
# 2    8.045214  166.542629  -1112.623480  5781.667847  -76.735634  ...
# 3   10.474788  197.200789   -531.988030    61.498784  -84.596547  ...
# 4    9.720006  226.625042   -502.499350 -3170.028608  -95.892612  ...
# 5    7.868458  124.925471   -237.640755 -2109.988854  -95.455721  ...
#
#       SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  Utilities  \
# Id
# 1  -104.645827  -351.621116     0.0   -498.228775 -5165.503476        0.0
# 2  -229.800309  -217.525460     0.0   -546.013970  2783.676113        0.0
# 3   -91.178667  -323.291461     0.0   -178.772620 -5157.340087        0.0
# 4   -89.323269  -344.762081     0.0   -608.018763 -5882.195324        0.0
# 5  -481.118248  -384.072813     0.0  -4071.644413 -4866.753785        0.0
#
#      WoodDeckSF    YearBuilt  YearRemodAdd      YrSold
# Id
# 1   -944.040092  3870.961681   2219.313761   17.478037
# 2   2388.081749   340.160052  -4310.041670  413.350114
# 3   -919.487875  3877.023405   2141.713106  -72.948518
# 4   -853.089042 -3740.803412  -4930.879276  555.382978
# 5    270.882130  2394.736098   1533.333106 -233.439195
#
# [5 rows x 73 columns]

# %% [markdown]
# #### Summarize explanability of the predictions

# %%
predictor_load.modify_mask(max_contrib=10)

# %%
explanation = predictor_load.summarize()

# %%
explanation.head()
# Out:
#            ypred    feature_1 value_1 contribution_1    feature_2 value_2  \
# 1  206462.878757  OverallQual       7        8248.82  TotalBsmtSF     856
# 2  181127.963794  OverallQual       6       -14555.9    GrLivArea    1262
# 3  221478.052244    GrLivArea    1786        15708.3  OverallQual       7
# 4  184788.423141  OverallQual       7        8188.35   GarageArea     642
# 5  256637.518234  OverallQual       8        58568.4    GrLivArea    2198
#
#   contribution_2    feature_3 value_3 contribution_3  ... contribution_7  \
# 1        -5165.5    YearBuilt    2003        3870.96  ...        2219.31
# 2       -10016.3  OverallCond       8         6899.3  ...        2783.68
# 3        11084.5   GarageArea     608        5998.61  ...        2141.71
# 4        6651.57  TotalBsmtSF     756        -5882.2  ...        2969.71
# 5        16891.9   GarageArea     836        15161.9  ...       -4866.75
#
#       feature_8 value_8 contribution_8     feature_9 value_9 contribution_9  \
# 1    MSSubClass       5        2069.88  BsmtFinType1     NaN         1756.7
# 2  Neighborhood     298        2753.12    WoodDeckSF    1262        2388.08
# 3  BsmtFullBath       5        1806.24   OverallCond     NaN       -1630.02
# 4    MSSubClass       5        2767.33   OverallCond     NaN       -1875.09
# 5   KitchenQual      12       -4611.78        MoSold       9       -4240.05
#
#      feature_10 value_10 contribution_10
# 1   OverallCond      NaN         -1507.9
# 2      1stFlrSF      NaN         1629.06
# 3  BsmtFinType1      NaN         1440.23
# 4  Neighborhood      NaN         1585.21
# 5  TotRmsAbvGrd      NaN        -4071.64
#
# [5 rows x 31 columns]
